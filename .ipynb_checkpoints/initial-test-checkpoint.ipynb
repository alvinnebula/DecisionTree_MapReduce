# %% [markdown]
# ## Spark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('tree').getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/05 14:30:22 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import pyspark
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StringIndexer, MinMaxScaler
from pyspark.ml.classification import DecisionTreeClassifier,GBTClassifier,RandomForestClassifier
from pyspark.ml import Pipeline

# %%
df = spark.read.csv("../../../data/p_dsi/big_data_scaling_sp23/project/DT-MapReduce/adult.csv", inferSchema = True, header = True)

# %%
df
# Out:
# DataFrame[age: int, workclass: string, fnlwgt: int, education: string, education.num: int, marital.status: string, occupation: string, relationship: string, race: string, sex: string, capital.gain: int, capital.loss: int, hours.per.week: int, native.country: string, income: string]

# %%
df.show(10)
# Out:
# +---+-----------+------+------------+-------------+--------------+-----------------+--------------+-----+------+------------+------------+--------------+--------------+------+
# |age|  workclass|fnlwgt|   education|education.num|marital.status|       occupation|  relationship| race|   sex|capital.gain|capital.loss|hours.per.week|native.country|income|
# +---+-----------+------+------------+-------------+--------------+-----------------+--------------+-----+------+------------+------------+--------------+--------------+------+
# | 90|          ?| 77053|     HS-grad|            9|       Widowed|                ?| Not-in-family|White|Female|           0|        4356|            40| United-States| <=50K|
# | 82|    Private|132870|     HS-grad|            9|       Widowed|  Exec-managerial| Not-in-family|White|Female|           0|        4356|            18| United-States| <=50K|
# ...

# %%
train, test = df.randomSplit([0.8,0.2])

# %%
gender_indexer = StringIndexer(inputCol='workclass',outputCol='wc_fixed')

# %%
df_fixed = gender_indexer.fit(df).transform(df)

# %%
df_fixed.show(10)
# Out:
# +---+-----------+------+------------+-------------+--------------+-----------------+--------------+-----+------+------------+------------+--------------+--------------+------+--------+
# |age|  workclass|fnlwgt|   education|education.num|marital.status|       occupation|  relationship| race|   sex|capital.gain|capital.loss|hours.per.week|native.country|income|wc_fixed|
# +---+-----------+------+------------+-------------+--------------+-----------------+--------------+-----+------+------------+------------+--------------+--------------+------+--------+
# | 90|          ?| 77053|     HS-grad|            9|       Widowed|                ?| Not-in-family|White|Female|           0|        4356|            40| United-States| <=50K|     3.0|
# | 82|    Private|132870|     HS-grad|            9|       Widowed|  Exec-managerial| Not-in-family|White|Female|           0|        4356|            18| United-States| <=50K|     0.0|
# ...

# %% [markdown]
# ### Pandas

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from skopt import BayesSearchCV
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, MinMaxScaler, Normalizer, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import janitor

# %%
df_pd = pd.read_csv("../../../data/p_dsi/big_data_scaling_sp23/project/DT-MapReduce/adult.csv").clean_names()

# %%
df_pd
# Out:
#        age workclass  fnlwgt     education  education_num      marital_status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from pandas.api.types import is_categorical_dtype

# %%
df_pd["marital_relation"] = df_pd["marital_status"] + "_" + df_pd["relationship"]
df_pd = df_pd.drop(["sex","race","education_num", "native_country", "marital_status","relationship"], axis = 1)

# %%
df_pd["income"].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df_pd["income"] = df_pd["income"].replace(["<=50K",">50K"], [0,1])

# %%
df_pd["income"].unique()
# Out:
# array([0, 1])

# %%
train, test = train_test_split(df_pd, random_state = 42069, train_size = 0.8, stratify = df_pd["income"])

# %% [markdown]
# ### Data Deduplication

# %%
train_0 = train[train["income"] == 0]
train_0.head()
# Out:
#        age    workclass  fnlwgt     education         occupation  \
# 17562   67            ?   92061       HS-grad                  ?
# 7517    19      Private  262515          11th      Other-service
# 26868   31      Private   87535  Some-college  Machine-op-inspct
# 30696   34  Federal-gov  194740  Some-college       Adm-clerical
# 16586   61      Private  273803       HS-grad       Craft-repair
#
#        capital_gain  capital_loss  hours_per_week  income  \
# 17562             0             0               8       0
# 7517              0             0              20       0
# 26868             0             0              25       0
# 30696             0             0              40       0
# 16586             0             0              40       0
#
#                    marital_relation
# 17562        Widowed_Other-relative
# 7517   Never-married_Other-relative
# 26868   Never-married_Not-in-family
# 30696   Never-married_Not-in-family
# 16586    Married-civ-spouse_Husband

# %%
train_1 = train[train["income"] == 1]
train_1.head()
# Out:
#        age workclass  fnlwgt     education      occupation  capital_gain  \
# 20770   45   Private  167187     Bachelors  Prof-specialty             0
# 15247   48   Private  267912     Bachelors   Other-service             0
# 2050    54   Private  104501  Some-college           Sales         15024
# 2525    34         ?  166545  Some-college               ?          7688
# 11432   26   Private   84619     Bachelors    Craft-repair             0
#
#        capital_loss  hours_per_week  income             marital_relation
# 20770             0              40       1  Never-married_Not-in-family
# 15247             0              50       1  Never-married_Not-in-family
# 2050              0              40       1   Married-civ-spouse_Husband
# 2525              0               6       1      Married-civ-spouse_Wife
# 11432             0              40       1   Married-civ-spouse_Husband

# %%
train_0 = train_0.drop_duplicates()

# %% [markdown]
# ### Class Balancing

# %%
#rand_list = list(np.random.randint(0, len(train_0), len(train_1)))

# %%
#train_0 = train_0.iloc[rand_list,]
#train_0.shape

# %%
train_new = pd.concat([train_0, train_1], axis = 0)
train_new.head()
# Out:
#        age    workclass  fnlwgt     education         occupation  \
# 17562   67            ?   92061       HS-grad                  ?
# 7517    19      Private  262515          11th      Other-service
# 26868   31      Private   87535  Some-college  Machine-op-inspct
# 30696   34  Federal-gov  194740  Some-college       Adm-clerical
# 16586   61      Private  273803       HS-grad       Craft-repair
#
#        capital_gain  capital_loss  hours_per_week  income  \
# 17562             0             0               8       0
# 7517              0             0              20       0
# 26868             0             0              25       0
# 30696             0             0              40       0
# 16586             0             0              40       0
#
#                    marital_relation
# 17562        Widowed_Other-relative
# 7517   Never-married_Other-relative
# 26868   Never-married_Not-in-family
# 30696   Never-married_Not-in-family
# 16586    Married-civ-spouse_Husband

# %%
x_train, y_train = train_new.drop("income", axis = 1), train_new["income"]
x_test, y_test = test.drop("income", axis = 1), test["income"]

# %%
num = []
cat = []
stri = []
columns = list(x_train.columns)
for col in columns:
    if is_numeric_dtype(x_train[col]):
        num.append(col)
    elif is_string_dtype(x_train[col]):
        stri.append(col)
    elif is_category_dtype(x_train[col]):
        cat.append(col)

# %%
num, stri, cat
# Out:
# (['age', 'fnlwgt', 'capital_gain', 'capital_loss', 'hours_per_week'],
#  ['workclass', 'education', 'occupation', 'marital_relation'],
#  [])

# %%
df_pd["education"].unique()
# Out:
# array(['HS-grad', 'Some-college', '7th-8th', '10th', 'Doctorate',
#        'Prof-school', 'Bachelors', 'Masters', '11th', 'Assoc-acdm',
#        'Assoc-voc', '1st-4th', '5th-6th', '12th', '9th', 'Preschool'],
#       dtype=object)

# %%
len(df_pd["education"].unique())
# Out:
# 16

# %%
stri.remove("education")

# %%
educ = ["education"]

# %%
x_train
# Out:
#        age     workclass  fnlwgt     education         occupation  \
# 17562   67             ?   92061       HS-grad                  ?
# 7517    19       Private  262515          11th      Other-service
# 26868   31       Private   87535  Some-college  Machine-op-inspct
# 30696   34   Federal-gov  194740  Some-college       Adm-clerical
# 16586   61       Private  273803       HS-grad       Craft-repair
# ...    ...           ...     ...           ...                ...
# 16418   28       Private  338376  Some-college       Adm-clerical
# 5918    32       Private  190511  Some-college    Exec-managerial
# 9729    39       Private  126675       Masters              Sales
# 7050    37       Private  286026       HS-grad     Prof-specialty
# 30741   35  Self-emp-inc   89622  Some-college              Sales
#
#        capital_gain  capital_loss  hours_per_week  \
# 17562             0             0               8
# 7517              0             0              20
# ...

# %%
x_train.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'occupation', 'capital_gain',
#        'capital_loss', 'hours_per_week', 'marital_relation'],
#       dtype='object')

# %%
min_max = MinMaxScaler()
ohe = OneHotEncoder()
ordi = ordi = OrdinalEncoder(categories = [["Preschool", "1st-4th","5th-6th", "7th-8th", "9th", "10th", 
                                            "11th", "12th", "HS-grad", "Some-college",
                                            "Assoc-voc","Assoc-acdm","Bachelors", "Masters","Prof-school","Doctorate"]])

# %%
def column_transform(df, columns):
    new_df = df.copy()
    for col in columns:
        if col in num:
            ct = ColumnTransformer([("min_max", min_max, [col])])
            new_df[col + "_scaled"] = ct.fit_transform(df)
        elif col in stri:
            elements = sorted(df[col].unique())
            ct2 = ColumnTransformer([("ohe", ohe, [col])])
            if len(elements) > 2:
                x = ct2.fit_transform(df).toarray()
            elif len(elements) <= 2:
                x = np.array(ct2.fit_transform(df))
            for i in range(len(elements)):
                new_df[col + "_" + elements[i].lower()] = x[:,i]
        elif col in educ:
            ct3 = ColumnTransformer([("ord", ordi, [col])])
            x = ct3.fit_transform(df)
            new_df[col + "_new"] = x
    new_df = new_df.drop(columns, axis = 1)
    return new_df

# %%
new_train_data = column_transform(x_train, list(x_train.columns))
### This is what is going to be ran through our decision tree model.

# %%
new_train_data.head()
# Out:
#        age_scaled  workclass_?  workclass_federal-gov  workclass_local-gov  \
# 17562    0.684932          1.0                    0.0                  0.0
# 7517     0.027397          0.0                    0.0                  0.0
# 26868    0.191781          0.0                    0.0                  0.0
# 30696    0.232877          0.0                    1.0                  0.0
# 16586    0.602740          0.0                    0.0                  0.0
#
#        workclass_never-worked  workclass_private  workclass_self-emp-inc  \
# 17562                     0.0                0.0                     0.0
# 7517                      0.0                1.0                     0.0
# 26868                     0.0                1.0                     0.0
# 30696                     0.0                0.0                     0.0
# 16586                     0.0                1.0                     0.0
#
# ...

# %%
new_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26032 entries, 17562 to 30741
# Data columns (total 59 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   age_scaled                                             26032 non-null  float64
#  1   workclass_?                                            26032 non-null  float64
#  2   workclass_federal-gov                                  26032 non-null  float64
#  3   workclass_local-gov                                    26032 non-null  float64
#  4   workclass_never-worked                                 26032 non-null  float64
#  5   workclass_private                                      26032 non-null  float64
#  6   workclass_self-emp-inc                                 26032 non-null  float64
#  7   workclass_self-emp-not-inc                             26032 non-null  float64
# ...

# %%
def column_fit_transform(train, other, columns):
    new_df = other.copy()
    for col in columns:
        if col in num:
            ct = ColumnTransformer([("min_max", min_max, [col])])
            ct.fit(train)
            new_df[col + "_scaled"] = ct.transform(other)
        elif col in stri:
            elements = sorted(other[col].unique())
            ct2 = ColumnTransformer([("ohe", ohe, [col])])
            if len(elements) > 2:
                ct2.fit(train)
                x = ct2.transform(other).toarray()
            elif len(elements) <= 2:
                ct2.fit(train)
                x = np.array(ct2.transform(other))
            for i in range(len(elements)):
                new_df[col + "_" + elements[i].lower()] = x[:,i]
        elif col in educ:
            ct3 = ColumnTransformer([("ord", ordi, [col])])
            ct3.fit(train)
            x = ct3.transform(other)
            new_df[col + "_new"] = x
        
    new_df = new_df.drop(columns, axis = 1)
    return new_df

# %%
new_test_data = column_fit_transform(x_train, x_test, x_train.columns)
new_test_data.head()
### This is what we are going to use to evaluate our decision tree model's performance
# Out:
#        age_scaled  workclass_?  workclass_federal-gov  workclass_local-gov  \
# 3416     0.328767          0.0                    0.0                  0.0
# 13174    0.534247          0.0                    0.0                  0.0
# 23415    0.520548          0.0                    0.0                  1.0
# 21725    0.041096          0.0                    0.0                  0.0
# 27534    0.315068          0.0                    0.0                  0.0
#
#        workclass_never-worked  workclass_private  workclass_self-emp-inc  \
# 3416                      0.0                1.0                     0.0
# 13174                     0.0                0.0                     1.0
# 23415                     0.0                0.0                     0.0
# 21725                     0.0                1.0                     0.0
# 27534                     0.0                1.0                     0.0
#
# ...

# %%
new_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6513 entries, 3416 to 18493
# Data columns (total 57 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   age_scaled                                             6513 non-null   float64
#  1   workclass_?                                            6513 non-null   float64
#  2   workclass_federal-gov                                  6513 non-null   float64
#  3   workclass_local-gov                                    6513 non-null   float64
#  4   workclass_never-worked                                 6513 non-null   float64
#  5   workclass_private                                      6513 non-null   float64
#  6   workclass_self-emp-inc                                 6513 non-null   float64
#  7   workclass_self-emp-not-inc                             6513 non-null   float64
# ...

# %%
test_col, train_col = list(new_test_data.columns), list(new_train_data.columns)

# %%
len(test_col), len(train_col)
# Out:
# (57, 59)

# %%
set(test_col)
# Out:
# {'age_scaled',
#  'capital_gain_scaled',
#  'capital_loss_scaled',
#  'education_new',
#  'fnlwgt_scaled',
#  'hours_per_week_scaled',
#  'marital_relation_divorced_not-in-family',
#  'marital_relation_divorced_other-relative',
#  'marital_relation_divorced_own-child',
#  'marital_relation_divorced_unmarried',
#  'marital_relation_married-af-spouse_husband',
#  'marital_relation_married-af-spouse_wife',
#  'marital_relation_married-civ-spouse_husband',
#  'marital_relation_married-civ-spouse_not-in-family',
#  'marital_relation_married-civ-spouse_other-relative',
#  'marital_relation_married-civ-spouse_own-child',
#  'marital_relation_married-civ-spouse_wife',
#  'marital_relation_married-spouse-absent_not-in-family',
#  'marital_relation_married-spouse-absent_other-relative',
#  'marital_relation_married-spouse-absent_own-child',
#  'marital_relation_married-spouse-absent_unmarried',
#  'marital_relation_never-married_not-in-family',
# ...

# %%
missing = list(set(train_col).difference(set(test_col)))

# %%
for miss in missing:
    new_test_data[missing] = 0.0
new_test_data.head()
# Out:
#        age_scaled  workclass_?  workclass_federal-gov  workclass_local-gov  \
# 3416     0.328767          0.0                    0.0                  0.0
# 13174    0.534247          0.0                    0.0                  0.0
# 23415    0.520548          0.0                    0.0                  1.0
# 21725    0.041096          0.0                    0.0                  0.0
# 27534    0.315068          0.0                    0.0                  0.0
#
#        workclass_never-worked  workclass_private  workclass_self-emp-inc  \
# 3416                      0.0                1.0                     0.0
# 13174                     0.0                0.0                     1.0
# 23415                     0.0                0.0                     0.0
# 21725                     0.0                1.0                     0.0
# 27534                     0.0                1.0                     0.0
#
# ...

# %% [markdown]
# #### Training

# %%
ct = ColumnTransformer([("ohe", OneHotEncoder(handle_unknown="ignore"), stri), ("ord", ordi, ["education"]), ("min_max", MinMaxScaler(), num)])

# %%
pipeline = Pipeline([("ct", ct), ("dc", DecisionTreeClassifier(criterion="entropy"))])

# %%
import numpy as np
max_features = list(np.arange(3,20))
max_depth = list(np.arange(3,20))

# %%
param_grid = [{"dc__max_features":max_features, "dc__max_depth": max_depth}]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
bayes_search = BayesSearchCV(pipeline, param_grid, cv = 5, n_iter = 30)

# %%
bayes_search.fit(x_train, y_train);

# %%
bayes_search.best_params_
# Out:
# OrderedDict([('dc__max_depth', 13), ('dc__max_features', 19)])

# %%
bayes_search.best_score_
# Out:
# 0.8523352713600099

# %%
result = pd.DataFrame(bayes_search.cv_results_).sort_values("rank_test_score", ascending = True)

# %%
result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6        0.132366      0.007347         0.015414        0.001263
# 11       0.146378      0.024057         0.015945        0.001570
# 12       0.131884      0.025056         0.014509        0.000777
# 28       0.127397      0.020239         0.015109        0.001040
# 16       0.120886      0.023443         0.015203        0.000182
# 26       0.093126      0.016983         0.016327        0.003171
# 13       0.116862      0.019552         0.015948        0.002470
# 24       0.085870      0.008186         0.015003        0.000583
# 21       0.096461      0.022630         0.016275        0.002618
# 15       0.112350      0.014435         0.016650        0.002812
# 18       0.125636      0.023068         0.014950        0.000517
# 7        0.160091      0.008317         0.015234        0.000933
# 8        0.087832      0.007760         0.015023        0.001182
# ...

# %%
model = bayes_search.best_estimator_

# %%
model[1]
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=13, max_features=19)

# %%
total_list = list(model.steps[0][1].transformers_[0][1].get_feature_names()) + num + educ

# %%
from sklearn import tree
fig = plt.figure(figsize=(30,20))
_ = tree.plot_tree(model[1], 
                   feature_names= total_list,  
                   class_names=["<=50K", ">50K"],
                   filled=True)

# %%
#text_representation = tree.export_text(model[1])
#print(text_representation)

# %%
pred = model.predict(x_test)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      4945
#            1       0.71      0.62      0.66      1568
#
#     accuracy                           0.85      6513
#    macro avg       0.80      0.77      0.78      6513
# weighted avg       0.84      0.85      0.84      6513

# %%
conf = confusion_matrix(y_test,pred)

# %%
sns.heatmap(conf, annot = True, cmap = "RdBu")
# Out:
# <AxesSubplot:>
